# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
County_MedianListingPrice_AllHomes = "data/County_MedianListingPrice_AllHomes.csv"
DaysOnZillow_County = "data/DaysOnZillow_County.csv"
Sale_Counts_County = "data/Sale_Counts_County.csv"



# Read the Mouse and Drug Data and the Clinical Trial Data
Price = pd.read_csv(County_MedianListingPrice_AllHomes, encoding="ISO-8859-1")
Days = pd.read_csv(DaysOnZillow_County, encoding="ISO-8859-1")
Sale = pd.read_csv(Sale_Counts_County, encoding="ISO-8859-1")



Price = Price.dropna(how='all')
Days = Days.dropna(how='all')
Sale = Sale.dropna(how='all')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-f18e5e168e39> in <module>
#      17
#      18 # Read the Mouse and Drug Data and the Clinical Trial Data
# ---> 19 Price = pd.read_csv(County_MedianListingPrice_AllHomes, encoding="ISO-8859-1")
#      20 Days = pd.read_csv(DaysOnZillow_County, encoding="ISO-8859-1")
#      21 Sale = pd.read_csv(Sale_Counts_County, encoding="ISO-8859-1")
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# ~\AppData\Local\Continuum\anaconda3\envs\pythondata\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'data/County_MedianListingPrice_AllHomes.csv' does not exist: b'data/County_MedianListingPrice_AllHomes.csv'

# %%
#Remove Columns
Sales = Sale.drop(labels=['RegionID','StateName','SizeRank','2008-03', '2008-04', '2008-05', '2008-06', '2008-07', 
                          '2008-08', '2008-09', '2008-10', '2008-11', '2008-12', '2009-01',
                          '2009-02', '2009-03', '2009-04', '2009-05', '2009-06', '2009-07', 
                          '2009-08', '2009-09', '2009-10', '2009-11', '2009-12'], axis=1)

Prices = Price.drop(labels=['State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS','SizeRank'],axis=1) 
Days = Days.drop(labels=['SizeRank', 'RegionID', 'RegionType', 'StateName'],axis=1)

#sale_.head(1)

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 8EAE-FA34
#
#  Directory of C:\Users\badr3\Desktop\Project-1
#
# 06/30/2019  02:03 PM    <DIR>          .
# 06/30/2019  02:03 PM    <DIR>          ..
# 06/30/2019  02:03 PM    <DIR>          .ipynb_checkpoints
# 06/29/2019  11:19 AM                 0 AC-main.py
# 06/29/2019  10:44 PM            13,530 Data.ipynb
# 06/29/2019  11:19 AM                 0 main.py
# 06/29/2019  11:19 AM                33 README.md
# 06/29/2019  11:19 AM                 0 test.txt
# 06/29/2019  11:21 AM                 0 test1.py
#                6 File(s)         13,563 bytes
#                3 Dir(s)  908,419,674,112 bytes free

# %%
#Add extra column for each table

Days['Type']='Day'
Sales['Type']='Sale'
Prices['Type']='Price'

# %%
# 

PD = Prices.append(Days, ignore_index=True)
PDM = PD.append(Sales, ignore_index=True)
PDM.shape
# Out:
# (5919, 115)

# %%
#Merge two cells in one
PDM["County"] = PDM["RegionName"].map(str) + PDM["Type"]

# %%
#tanspose table
PDM.set_index(['County'],inplace=True)
PDM_ = PDM.transpose()


PDM_.head(5)
# Out:
# County  Los Angeles CountyPrice Cook CountyPrice Harris CountyPrice  \
# 2010-01                  399000           244900             149900
# 2010-02                  389000           249000             152900
# 2010-03                  399000           249000             154755
# 2010-04                  398800           249000             154900
# 2010-05                  399000           245000             155000
#
# County  Maricopa CountyPrice San Diego CountyPrice Orange CountyPrice  \
# 2010-01               179900                399000             550000
# 2010-02               175900                399000             529000
# 2010-03               174900                399500             510000
# 2010-04               169900                399990             519000
# 2010-05               165000                400000             519900
#
# County  Kings CountyPrice Miami-Dade CountyPrice Dallas CountyPrice  \
# 2010-01            459000                    NaN             159900
# 2010-02            469000                    NaN             159990
# 2010-03            459000                    NaN             164905
# 2010-04            459000                    NaN             169000
# 2010-05            450000                    NaN             168000
#
# County  Queens CountyPrice  ... Mineral CountySale McMullen CountySale  \
# 2010-01             409000  ...                  0                   0
# 2010-02             400000  ...                  0                   0
# 2010-03             375000  ...                  0                   0
# 2010-04             375000  ...                  0                   0
# 2010-05             375000  ...                  0                   0
#
# County  San Juan CountySale Banner CountySale Yakutat BoroughSale  \
# 2010-01                   0                 0                   0
# 2010-02                   2                 0                   0
# 2010-03                   0                 0                   0
# 2010-04                   1                 0                   0
# 2010-05                   0                 0                   0
#
# County  Thomas CountySale McPherson CountySale Petroleum CountySale  \
# 2010-01                 0                    0                    0
# 2010-02                 0                    0                    0
# 2010-03                 0                    0                    0
# 2010-04                 0                    0                    0
# 2010-05                 0                    0                    0
#
# County  Blaine CountySale Kenedy CountySale
# 2010-01                 0                 0
# 2010-02                 0                 0
# 2010-03                 0                 0
# 2010-04                 0                 0
# 2010-05                 0                 0
#
# [5 rows x 5919 columns]

# %%
PDM.shape
# Out:
# (5919, 115)

# %%
# M_table = Sales.merge(Prices, on=['RegionName'], suffixes=(' Sale', ' Price'))
# M_table = M_table.merge(Days, on=['RegionName'], suffixes=('Days', ''))


# columnnames = Days.columns.tolist()
# for col in columnnames:
#     if col != "RegionName":
#         M_table = M_table.rename(columns={col: f"{col} Day"})
        
# M_table.head(5)
