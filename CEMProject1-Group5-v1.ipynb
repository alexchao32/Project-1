# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load in csv

filen = "County_MedianListingPrice_AllHomes.csv"

cm_pric_df = pd.read_csv(filen, encoding="ISO-8859-1")

cn = cm_pric_df.columns
cn
# Out:
# Index(['RegionName', 'State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS',
#        'SizeRank', '2010-01', '2010-02', '2010-03', '2010-04',
#        ...
#        '2018-08', '2018-09', '2018-10', '2018-11', '2018-12', '2019-01',
#        '2019-02', '2019-03', '2019-04', '2019-05'],
#       dtype='object', length=119)

# %%
cm_pric_df.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 0                 37         1  399000.0  389000.0  399000.0  398800.0  ...
# 1                 31         2  244900.0  249000.0  249000.0  249000.0  ...
# 2                201         3  149900.0  152900.0  154755.0  154900.0  ...
# 3                 13         4  179900.0  175900.0  174900.0  169900.0  ...
# 4                 73         5  399000.0  399000.0  399500.0  399990.0  ...
#
#     2018-08   2018-09   2018-10   2018-11   2018-12   2019-01   2019-02  \
# 0  659000.0  660000.0  662050.0  659000.0  649999.0  649900.0  650000.0
# 1  288900.0  289000.0  285000.0  280176.5  278000.0  280000.0  289900.0
# 2  278000.0  279500.0  279000.0  279000.0  275600.0  276995.0  279000.0
# 3  308000.0  305990.0  309900.0  308000.0  307945.0  309990.0  310000.0
# 4  649000.0  649000.0  637000.0  635000.0  635000.0  635000.0  639000.0
#
#     2019-03   2019-04   2019-05
# 0  665000.0  675000.0  679000.0
# 1  299000.0  300000.0  300000.0
# 2  279900.0  285000.0  283907.0
# 3  314900.0  317990.0  318000.0
# 4  644000.0  650000.0  659650.0
#
# [5 rows x 119 columns]

# %%
unique = cm_pric_df["State"]
unique.head()
# Out:
# 0    CA
# 1    IL
# 2    TX
# 3    AZ
# 4    CA
# Name: State, dtype: object

# %%
#Select only the data for counties in North Carolina (NC)
nc_df1 = cm_pric_df.loc[cm_pric_df["State"]=="NC"]
nc_df1.head()
# Out:
#              RegionName State                       Metro  StateCodeFIPS  \
# 48   Mecklenburg County    NC  Charlotte-Concord-Gastonia             37
# 55          Wake County    NC                     Raleigh             37
# 134     Guilford County    NC       Greensboro-High Point             37
# 183      Forsyth County    NC               Winston-Salem             37
# 198   Cumberland County    NC                Fayetteville             37
#
#      MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 48                 119        49  190000.0  194900.0  192000.0  194400.0  ...
# 55                 183        56  248000.0  245000.0  239900.0  239999.0  ...
# 134                 81       135  159900.0  159900.0  159900.0  159900.0  ...
# 183                 67       184  154900.0  156700.0  159900.0  159900.0  ...
# 198                 51       199       NaN       NaN       NaN       NaN  ...
#
#       2018-08   2018-09   2018-10   2018-11   2018-12   2019-01   2019-02  \
# 48   305000.0  309000.0  307995.0  305320.0  304900.0  304945.0  314500.0
# 55   350000.0  353000.0  350000.0  349900.0  349900.0  345000.0  345000.0
# 134  189900.0  189995.0  189900.0  189900.0  191400.0  194775.0  196000.0
# 183  195201.0  198567.5  195000.0  195900.0  197000.0  198170.0  201900.0
# 198  149900.0  149999.0  150000.0  150000.0  150000.0  155000.0  163000.0
#
#       2019-03   2019-04   2019-05
# 48   314994.5  320000.0  319900.0
# 55   349000.0  353500.0  350000.0
# 134  207990.0  212900.0  213245.0
# 183  215000.0  224900.0  219900.0
# 198  165900.0  172500.0  169700.0
#
# [5 rows x 119 columns]

# %%
#Sort Counties by average price of property in 2019-05 - from the largest to the lowest
nc_df1_sorted = nc_df1.sort_values(by ='2019-05',ascending=False )
nc_df1_sorted.head()
# Out:
#                RegionName State               Metro  StateCodeFIPS  \
# 817        Chatham County    NC  Durham-Chapel Hill             37
# 1298          Dare County    NC    Kill Devil Hills             37
# 459         Orange County    NC  Durham-Chapel Hill             37
# 1153       Jackson County    NC           Cullowhee             37
# 1320  Transylvania County    NC             Brevard             37
#
#       MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  \
# 817                  37       818  339000.0  339665.0  320000.0  315000.0
# 1298                 55      1299  394900.0  389900.0  384900.0  379000.0
# 459                 135       460  320000.0  324900.0  324900.0  324700.0
# 1153                 99      1154  299000.0  299250.0  299900.0  299000.0
# 1320                175      1321  342000.0  337000.0  326250.0  324900.0
#
#       ...   2018-08   2018-09   2018-10   2018-11   2018-12   2019-01  \
# 817   ...  437190.0  453000.0  459900.0  467854.5  479900.0  475000.0
# 1298  ...  416000.0  419000.0  424900.0  419000.0  422250.0  425000.0
# 459   ...  399000.0  399000.0  389000.0  389900.0  386750.0  375000.0
# 1153  ...  385000.0  379900.0  380000.0  379000.0  379900.0  379900.0
# 1320  ...  346500.0  354250.0  359000.0  362000.0  365000.0  379000.0
#
#        2019-02   2019-03   2019-04   2019-05
# 817   470000.0  482545.0  475000.0  481000.0
# 1298  419000.0  420000.0  423900.0  425000.0
# 459   391450.0  402500.0  419900.0  413000.0
# 1153  369000.0  375000.0  379450.0  385000.0
# 1320  377000.0  365000.0  374900.0  384000.0
#
# [5 rows x 119 columns]

# %%
df_month = nc_df1_sorted.iloc[:,6:]
df_month['County']= nc_df1_sorted['RegionName']
countyl = df_month['County'].unique()
df_month2 = df_month.set_index('County')
df_month2.head()
# Out:
#                       2010-01   2010-02   2010-03   2010-04   2010-05  \
# County
# Chatham County       339000.0  339665.0  320000.0  315000.0  314752.5
# Dare County          394900.0  389900.0  384900.0  379000.0  374900.0
# Orange County        320000.0  324900.0  324900.0  324700.0  329900.0
# Jackson County       299000.0  299250.0  299900.0  299000.0  350000.0
# Transylvania County  342000.0  337000.0  326250.0  324900.0  329000.0
#
#                       2010-06   2010-07   2010-08   2010-09   2010-10  ...  \
# County                                                                 ...
# Chatham County       309075.0  318000.0  313950.0  324000.0  319700.0  ...
# Dare County          369900.0  365000.0  368000.0  369900.0  369950.0  ...
# Orange County        328950.0  324900.0  325000.0  329000.0  325000.0  ...
# Jackson County       349000.0  319000.0  349000.0  333500.0  327000.0  ...
# Transylvania County  329250.0  335000.0  325000.0  325000.0  325000.0  ...
#
#                       2018-08   2018-09   2018-10   2018-11   2018-12  \
# County
# Chatham County       437190.0  453000.0  459900.0  467854.5  479900.0
# Dare County          416000.0  419000.0  424900.0  419000.0  422250.0
# Orange County        399000.0  399000.0  389000.0  389900.0  386750.0
# Jackson County       385000.0  379900.0  380000.0  379000.0  379900.0
# Transylvania County  346500.0  354250.0  359000.0  362000.0  365000.0
#
#                       2019-01   2019-02   2019-03   2019-04   2019-05
# County
# Chatham County       475000.0  470000.0  482545.0  475000.0  481000.0
# Dare County          425000.0  419000.0  420000.0  423900.0  425000.0
# Orange County        375000.0  391450.0  402500.0  419900.0  413000.0
# Jackson County       379900.0  369000.0  375000.0  379450.0  385000.0
# Transylvania County  379000.0  377000.0  365000.0  374900.0  384000.0
#
# [5 rows x 113 columns]

# %%
dfm_trasnp = df_month2.transpose()
dfm_trasnp.head()
# Out:
# County   Chatham County  Dare County  Orange County  Jackson County  \
# 2010-01        339000.0     394900.0       320000.0        299000.0
# 2010-02        339665.0     389900.0       324900.0        299250.0
# 2010-03        320000.0     384900.0       324900.0        299900.0
# 2010-04        315000.0     379000.0       324700.0        299000.0
# 2010-05        314752.5     374900.0       329900.0        350000.0
#
# County   Transylvania County  Buncombe County  Currituck County  Hyde County  \
# 2010-01             342000.0         260000.0          349450.0          NaN
# 2010-02             337000.0         250000.0          339900.0          NaN
# 2010-03             326250.0         249500.0          344900.0          NaN
# 2010-04             324900.0         248750.0          339850.0          NaN
# 2010-05             329000.0         249900.0          329900.0          NaN
#
# County   Watauga County  Polk County  ...  Rockingham County  Halifax County  \
# 2010-01        349000.0     350000.0  ...           117700.0        155950.0
# 2010-02        339900.0     345000.0  ...           115000.0        157500.0
# 2010-03        339000.0     329450.0  ...           118950.0        161250.0
# 2010-04        339000.0     327000.0  ...           116900.0        160000.0
# 2010-05        335000.0     325000.0  ...           115950.0        157000.0
#
# County   Scotland County  Lenoir County  Robeson County  Richmond County  \
# 2010-01              NaN       125333.0         99000.0          90000.0
# 2010-02              NaN       124900.0         99949.5          93000.0
# 2010-03              NaN       125616.5         99000.0          98950.0
# 2010-04              NaN       119900.0        105000.0          99900.0
# 2010-05              NaN       120000.0         98900.0          93900.0
#
# County   Washington County  Bertie County  Martin County  Edgecombe County
# 2010-01                NaN            NaN            NaN           74000.0
# 2010-02                NaN            NaN            NaN           76500.0
# 2010-03                NaN            NaN            NaN           74900.0
# 2010-04                NaN            NaN            NaN           75000.0
# 2010-05                NaN            NaN            NaN           75000.0
#
# [5 rows x 89 columns]

# %%
m1 = list (range(1, 114))

plt.figure(figsize=(15,10))

i = 0
for i in range(0,5):
    plt.plot(m1, dfm_trasnp[countyl[i]], label = countyl[i])
    plt.legend()
    i +=1

plt.legend(loc="best")
plt.xlabel("Months - 2010-01 to 2019-05")
plt.ylabel("Average Price (US$)")
plt.title("Average Price")
plt.grid()

plt.show()

# %% [markdown]
# # df2 = nc_df1_sorted

# %%
#Consolidate average price per year
obj = {}
years = ['2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019']
for year in years:
    arr = []
    
    if year == '2019':
        for i in range(1, 6):
            if i == 10 or i == 11 or i == 12:
                arr.append(str(year) + "-" + str(i))
            else: 
                arr.append(str(year) + "-0" + str(i))
    else:
        for i in range(1, 13):
            if i == 10 or i == 11 or i == 12:
                arr.append(str(year) + "-" + str(i))
            else: 
                arr.append(str(year) + "-0" + str(i))
    
    total = 0
    for val in arr:
        total += df2[val]
    obj[year] = total / len(arr)
    
yearly_totals = pd.DataFrame(obj)
yearly_totals['county'] = df2['RegionName']
yearly_totals.head()
# Out:
#                2010           2011           2012           2013  \
# 817   320442.291667  303619.125000  305311.458333  336777.083333
# 1298  374529.166667  360316.666667  344058.333333  349445.833333
# 459   325037.500000  298291.250000  285704.166667  301034.333333
# 1153  322883.333333  307991.666667  292932.375000  306387.083333
# 1320  326933.333333  304858.333333  293983.333333  302523.041667
#
#                2014           2015           2016           2017  \
# 817   368479.000000  390858.916667  436276.958333  447401.416667
# 1298  346412.500000  359464.583333  390295.833333  411816.500000
# 459   322783.333333  372951.666667  369691.666667  383312.500000
# 1153  296375.000000  304451.666667  321491.666667  343200.000000
# 1320  298133.333333  292450.000000  331908.333333  343402.083333
#
#                2018      2019               county
# 817   454302.875000  476709.0       Chatham County
# 1298  423991.666667  422580.0          Dare County
# 459   393540.000000  400370.0        Orange County
# 1153  372588.500000  377670.0       Jackson County
# 1320  349841.666667  375980.0  Transylvania County

# %%
#Set County as index
yt1 = yearly_totals.set_index("county")
yt1.head()
# Out:
#                               2010           2011           2012  \
# county
# Chatham County       320442.291667  303619.125000  305311.458333
# Dare County          374529.166667  360316.666667  344058.333333
# Orange County        325037.500000  298291.250000  285704.166667
# Jackson County       322883.333333  307991.666667  292932.375000
# Transylvania County  326933.333333  304858.333333  293983.333333
#
#                               2013           2014           2015  \
# county
# Chatham County       336777.083333  368479.000000  390858.916667
# Dare County          349445.833333  346412.500000  359464.583333
# Orange County        301034.333333  322783.333333  372951.666667
# Jackson County       306387.083333  296375.000000  304451.666667
# Transylvania County  302523.041667  298133.333333  292450.000000
#
#                               2016           2017           2018      2019
# county
# Chatham County       436276.958333  447401.416667  454302.875000  476709.0
# Dare County          390295.833333  411816.500000  423991.666667  422580.0
# Orange County        369691.666667  383312.500000  393540.000000  400370.0
# Jackson County       321491.666667  343200.000000  372588.500000  377670.0
# Transylvania County  331908.333333  343402.083333  349841.666667  375980.0

# %%
# Transpose annual average price per county
ytt = yt1.transpose()
ytt.head()
# Out:
# county  Chatham County    Dare County  Orange County  Jackson County  \
# 2010     320442.291667  374529.166667  325037.500000   322883.333333
# 2011     303619.125000  360316.666667  298291.250000   307991.666667
# 2012     305311.458333  344058.333333  285704.166667   292932.375000
# 2013     336777.083333  349445.833333  301034.333333   306387.083333
# 2014     368479.000000  346412.500000  322783.333333   296375.000000
#
# county  Transylvania County  Buncombe County  Currituck County  Hyde County  \
# 2010          326933.333333    249312.500000     343512.500000          NaN
# 2011          304858.333333    245150.000000     360256.250000          NaN
# 2012          293983.333333    249300.000000     352287.500000          NaN
# 2013          302523.041667    246720.833333     367032.500000          NaN
# 2014          298133.333333    265429.166667     364470.833333          NaN
#
# county  Watauga County    Polk County  ...  Rockingham County  Halifax County  \
# 2010     339429.166667  316487.500000  ...      115258.333333   155779.166667
# 2011     311058.333333  277441.666667  ...      114083.333333   137579.166667
# 2012     294716.666667  245325.000000  ...      109375.000000   128600.000000
# 2013     292491.666667  259683.333333  ...      116083.333333   116541.666667
# 2014     294224.916667  280341.666667  ...      115614.166667   118266.666667
#
# county  Scotland County  Lenoir County  Robeson County  Richmond County  \
# 2010                NaN  121733.291667   111812.458333    100241.666667
# 2011                NaN  117387.500000   123833.333333     96391.666667
# 2012                NaN  118441.250000   130278.958333     90889.583333
# 2013                NaN  115266.666667   121522.916667     86200.000000
# 2014                NaN  108441.583333   117883.333333     95108.333333
#
# county  Washington County  Bertie County  Martin County  Edgecombe County
# 2010                  NaN            NaN            NaN      76099.958333
# 2011                  NaN            NaN            NaN      73879.125000
# 2012                  NaN            NaN            NaN      73787.500000
# 2013                  NaN            NaN            NaN      76179.166667
# 2014                  NaN            NaN            NaN      75525.000000
#
# [5 rows x 89 columns]

# %%
#Get the list of counties
countyl = yearly_totals['county'].unique()
countyl
# Out:
# array(['Chatham County', 'Dare County', 'Orange County', 'Jackson County',
#        'Transylvania County', 'Buncombe County', 'Currituck County',
#        'Hyde County', 'Watauga County', 'Polk County', 'Wake County',
#        'Henderson County', 'Union County', 'Lincoln County',
#        'Mecklenburg County', 'Madison County', 'Pender County',
#        'New Hanover County', 'Macon County', 'Iredell County',
#        'Carteret County', 'Moore County', 'Brunswick County',
#        'Yancey County', 'Durham County', 'Cabarrus County',
#        'Warren County', 'Camden County', 'McDowell County', 'Ashe County',
#        'Haywood County', 'Granville County', 'Swain County',
#        'Pamlico County', 'Johnston County', 'Franklin County',
#        'Rutherford County', 'Avery County', 'Clay County',
#        'Catawba County', 'Person County', 'Davie County', 'Graham County',
#        'Alleghany County', 'Stanly County', 'Beaufort County',
#        'Mitchell County', 'Alamance County', 'Harnett County',
#        'Perquimans County', 'Gaston County', 'Forsyth County',
#        'Chowan County', 'Guilford County', 'Hoke County',
#        'Alexander County', 'Craven County', 'Pasquotank County',
#        'Burke County', 'Pitt County', 'Wilkes County', 'Davidson County',
#        'Caldwell County', 'Stokes County', 'Onslow County',
#        'Rowan County', 'Lee County', 'Sampson County', 'Cherokee County',
#        'Surry County', 'Randolph County', 'Wayne County',
#        'Cumberland County', 'Yadkin County', 'Vance County',
#        'Nash County', 'Cleveland County', 'Wilson County',
#        'Columbus County', 'Rockingham County', 'Halifax County',
#        'Scotland County', 'Lenoir County', 'Robeson County',
#        'Richmond County', 'Washington County', 'Bertie County',
#        'Martin County', 'Edgecombe County'], dtype=object)

# %%
#Plot the top five counties
y = list (range(2010, 2020))
print (y)

plt.figure(figsize=(15,10))

i = 0
for i in range(0,5):
    plt.plot(y, ytt[countyl[i]], label = countyl[i])
    plt.legend()
    i +=1

plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Price (US$)")
plt.title("Average Price")
plt.grid()

plt.show()
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
# Calculate growth by county by year and plot the top five (based on average price)

obj1 = {}
yearsC = ['2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020']

plt.figure(figsize=(15,10))

j=0
i = 0

for county in countyl:
    cdata = ytt[county]
   
    change1 = []
    current = cdata[0]
    
    #Calculate % change per year, and store values in change1
    for value in cdata:
        if current!=0 :
            change1.append(((value/current)-1)*100)
        else:
            change1.append(0)
        current = value

    obj1[county] = change1
    #Plot Survival rates for selected products
    if i < 5:
        plt.plot(y, change1, label=county)
        i += 1
                    
plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("% Change Year over Year")
plt.title("Average Price Change Year over Year")
plt.grid()

# %%
#Create a dataframe including the percentage change per year per county
y_change = pd.DataFrame(obj1)
y_change['years'] = years
y_change1 = y_change.set_index("years")
y_change1
# Out:
#        Chatham County  Dare County  Orange County  Jackson County  \
# years
# 2010         0.000000     0.000000       0.000000        0.000000
# 2011        -5.249983    -3.794765      -8.228666       -4.612089
# 2012         0.557387    -4.512235      -4.219729       -4.889513
# 2013        10.306074     1.565868       5.365748        4.593111
# 2014         9.413324    -0.868041       7.224757       -3.267789
# 2015         6.073594     3.767786      15.542418        2.725151
# 2016        11.620060     8.576992      -0.874108        5.596948
# 2017         2.549862     5.513937       3.684377        6.752378
# 2018         1.542565     2.956454       2.668188        8.563083
# 2019         4.931980    -0.332947       1.735529        1.363837
#
#        Transylvania County  Buncombe County  Currituck County  Hyde County  \
# years
# 2010              0.000000         0.000000          0.000000          NaN
# 2011             -6.752141        -1.669591          4.874277          NaN
# 2012             -3.567231         1.692841         -2.211967          NaN
# 2013              2.904827        -1.034563          4.185502          NaN
# 2014             -1.451033         7.582794         -0.697940          NaN
# 2015             -1.906306         8.608700         -0.045728          NaN
# 2016             13.492335        13.822279          4.578866          NaN
# 2017              3.462929         9.640329         -2.562097          NaN
# 2018              1.875231         3.564893         -5.479363          NaN
# 2019              7.471475        -0.832091          6.144708          NaN
#
#        Watauga County  Polk County  ...  Rockingham County  Halifax County  \
# years                               ...
# 2010         0.000000     0.000000  ...           0.000000        0.000000
# 2011        -8.358396   -12.337243  ...          -1.019449      -11.683205
# 2012        -5.253570   -11.576007  ...          -4.127100       -6.526545
# 2013        -0.754962     5.852780  ...           6.133333       -9.376620
# 2014         0.592581     7.955202  ...          -0.404164        1.480157
# 2015         0.116153     9.324931  ...           3.898023        5.545378
# 2016         1.174041     1.820382  ...           2.514759       -1.044796
# 2017         4.230615    11.658989  ...          -4.408814       -0.141677
# 2018         9.766325     3.898263  ...           7.171428       -3.793534
# 2019         3.651120    -1.621462  ...           4.134492       -0.612360
#
#        Scotland County  Lenoir County  Robeson County  Richmond County  \
# years
# 2010               NaN       0.000000        0.000000         0.000000
# 2011               NaN      -3.569929       10.750926        -3.840718
# 2012               NaN       0.897668        5.205081        -5.708049
# 2013               NaN      -2.680302       -6.720995        -5.159649
# 2014               NaN      -5.921125       -2.994977        10.334493
# 2015               NaN       5.237151       -2.092464         6.974415
# 2016               NaN       2.022710       -1.238520         5.324028
# 2017               NaN       0.594066        1.773116         4.265495
# 2018         -1.669888      -1.807250        0.021550         4.381876
# 2019         -9.244568       1.352850       -2.881356        -1.487674
#
#        Washington County  Bertie County  Martin County  Edgecombe County
# years
# 2010                 NaN            NaN            NaN          0.000000
# 2011                 NaN            NaN            NaN         -2.918311
# 2012                 NaN            NaN            NaN         -0.124020
# 2013                 NaN            NaN            NaN          3.241290
# 2014                 NaN            NaN            NaN         -0.858721
# 2015                 NaN            NaN            NaN          1.859208
# 2016                 NaN            NaN            NaN          2.039214
# 2017                 NaN            NaN            NaN         -0.796306
# 2018                 NaN            NaN            NaN          1.661469
# 2019                 NaN       1.637628            NaN         -8.395789
#
# [10 rows x 89 columns]

# %%
# Calculate the average price percent changes from 2010 to 2019

change = []  #List to store the %change for each county

#Calculate %change for each medicine
for county in countyl:
    dataC = ytt[county]                       #Get tumor volume data for medicine
    change.append(((dataC['2019']/dataC['2010'])-1)*100)   #Calculate %change for medicine and add to list (change)
    
# Display the data to confirm
print (change)
# Out:
# [48.7659439459653, 12.829663911355361, 23.17655655116717, 16.96794507820163, 15.002039151712898, 48.20079217849085, 8.4222553764419, nan, 4.121871278985556, 12.534934239108964, 46.10357282976629, 36.647021140294676, 49.794406056976335, nan, 66.74381288614299, 14.273347040363603, 26.48151969586372, 27.019301232718117, 1.9394208365694166, 35.54954995573492, -7.009754973500271, 3.1378419896924026, 12.944246358505351, 27.370833025352947, 65.74564036692124, 66.10416263310745, nan, 12.417374820152371, 44.82277248878233, -1.9778263039680555, 8.666203601741573, 45.91670389349773, 13.82581436554451, -13.942420003259636, 43.96961331215729, 39.79986440677965, 25.931832797427656, -9.774541217593935, 5.729945540826864, 34.91391579817271, nan, 17.25878408533226, -2.7727380669674617, 3.892498523331356, 37.5334554269604, 14.571815663357125, 19.84851504883396, 49.466289912404626, 23.487571701720846, -7.525237957888664, 56.532145907039165, 37.75771814043263, nan, 31.09059901939886, 40.130396033282054, 29.31240327216451, 2.1768920034815897, 10.63607319198374, nan, 28.42572323500503, 9.51619526098404, 23.111566916567504, 29.533163854864796, 16.787371843616448, -1.8668319022749458, 30.50988626421698, 6.641431145243781, 4.926650366748175, 4.630833118269484, nan, 17.419656421643115, 4.485677749360617, nan, nan, -1.1889152112831258, 16.3054766853028, 30.255667415079323, 7.949660479855147, 4.322654664195569, 13.978743402501625, -24.290261320779948, nan, -4.249693404194077, 0.7848335326378075, 14.613018538531875, nan, nan, nan, -4.704284222669852]

# %%
# Store all Relevant Percent Changes into a Data Frame
countyC_10_19 = pd.DataFrame({"County": countyl, "% Change": change})
countyC_10_19.head()
# Out:
#                 County   % Change
# 0       Chatham County  48.765944
# 1          Dare County  12.829664
# 2        Orange County  23.176557
# 3       Jackson County  16.967945
# 4  Transylvania County  15.002039

# %%
#Order counties (in descending) based on % change between 2010 to 2019
dfC = countyC_10_19.sort_values(by ='% Change',ascending=False)
dfC.head(10)
# Out:
#                 County   % Change
# 14  Mecklenburg County  66.743813
# 25     Cabarrus County  66.104163
# 24       Durham County  65.745640
# 50       Gaston County  56.532146
# 12        Union County  49.794406
# 47     Alamance County  49.466290
# 0       Chatham County  48.765944
# 5      Buncombe County  48.200792
# 10         Wake County  46.103573
# 31    Granville County  45.916704

# %%
#Graph % change from 2010 to 2019 from the largest to the smallest
plt.figure(figsize=(15,10))

i= 0
plt.grid()
plt.bar(dfC['County'], dfC["% Change"], color = 'green', align='center', alpha=0.5)
#plt.bar(fail_med['Medicine'], fail_med["Change"], color = 'red', align='center', alpha=0.5)

#plt.xticks(y_pos, objects)
plt.ylabel('% Change in Average Price')
plt.title('% Change in Average Price between 2010 and 2019')

plt.show()

# %%
y = list (range(2010, 2020))
print (y)

countyL1 = dfC['County'].unique()

print (countyL1)
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]
# ['Mecklenburg County' 'Cabarrus County' 'Durham County' 'Gaston County'
#  'Union County' 'Alamance County' 'Chatham County' 'Buncombe County'
#  'Wake County' 'Granville County' 'McDowell County' 'Johnston County'
#  'Hoke County' 'Franklin County' 'Forsyth County' 'Stanly County'
#  'Henderson County' 'Iredell County' 'Catawba County' 'Guilford County'
#  'Rowan County' 'Cleveland County' 'Caldwell County' 'Alexander County'
#  'Pitt County' 'Yancey County' 'New Hanover County' 'Pender County'
#  'Rutherford County' 'Harnett County' 'Orange County' 'Davidson County'
#  'Mitchell County' 'Randolph County' 'Davie County' 'Jackson County'
#  'Stokes County' 'Nash County' 'Transylvania County' 'Richmond County'
#  'Beaufort County' 'Madison County' 'Rockingham County' 'Swain County'
#  'Brunswick County' 'Dare County' 'Polk County' 'Camden County'
#  'Pasquotank County' 'Wilkes County' 'Haywood County' 'Currituck County'
#  'Wilson County' 'Lee County' 'Clay County' 'Sampson County'
#  'Cherokee County' 'Wayne County' 'Columbus County' 'Watauga County'
#  'Alleghany County' 'Moore County' 'Craven County' 'Macon County'
#  'Robeson County' 'Vance County' 'Onslow County' 'Ashe County'
#  'Graham County' 'Lenoir County' 'Edgecombe County' 'Carteret County'
#  'Perquimans County' 'Avery County' 'Pamlico County' 'Halifax County'
#  'Hyde County' 'Lincoln County' 'Warren County' 'Person County'
#  'Chowan County' 'Burke County' 'Surry County' 'Cumberland County'
#  'Yadkin County' 'Scotland County' 'Washington County' 'Bertie County'
#  'Martin County']

# %%
plt.figure(figsize=(15,10))

i = 0
for i in range(0,5):
    plt.plot(y, y_change1[countyL1[i]], label = countyL1[i])
    plt.legend()
    i +=1

plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("% Chage in Average Price (US$)")
plt.title("% Change")
plt.grid()

plt.show()

# %%
#Plot the top five counties
y = list (range(2010, 2020))
print (y)

plt.figure(figsize=(15,10))

i = 0
for i in range(0,5):
    plt.plot(y, ytt[countyL1[i]], label = countyL1[i])
    plt.legend()
    i +=1

plt.legend(loc="best")
plt.xlabel("Years")
plt.ylabel("Average Price (US$)")
plt.title("Average Price")
plt.grid()

plt.show()
# Out:
# [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019]

# %%
#ANALYSIS BY STATE AT THE US LEVEL

# %%
cm_pric_df.head()
# Out:
#            RegionName State                             Metro  StateCodeFIPS  \
# 0  Los Angeles County    CA    Los Angeles-Long Beach-Anaheim              6
# 1         Cook County    IL          Chicago-Naperville-Elgin             17
# 2       Harris County    TX  Houston-The Woodlands-Sugar Land             48
# 3     Maricopa County    AZ           Phoenix-Mesa-Scottsdale              4
# 4    San Diego County    CA                San Diego-Carlsbad              6
#
#    MunicipalCodeFIPS  SizeRank   2010-01   2010-02   2010-03   2010-04  ...  \
# 0                 37         1  399000.0  389000.0  399000.0  398800.0  ...
# 1                 31         2  244900.0  249000.0  249000.0  249000.0  ...
# 2                201         3  149900.0  152900.0  154755.0  154900.0  ...
# 3                 13         4  179900.0  175900.0  174900.0  169900.0  ...
# 4                 73         5  399000.0  399000.0  399500.0  399990.0  ...
#
#     2018-08   2018-09   2018-10   2018-11   2018-12   2019-01   2019-02  \
# 0  659000.0  660000.0  662050.0  659000.0  649999.0  649900.0  650000.0
# 1  288900.0  289000.0  285000.0  280176.5  278000.0  280000.0  289900.0
# 2  278000.0  279500.0  279000.0  279000.0  275600.0  276995.0  279000.0
# 3  308000.0  305990.0  309900.0  308000.0  307945.0  309990.0  310000.0
# 4  649000.0  649000.0  637000.0  635000.0  635000.0  635000.0  639000.0
#
#     2019-03   2019-04   2019-05
# 0  665000.0  675000.0  679000.0
# 1  299000.0  300000.0  300000.0
# 2  279900.0  285000.0  283907.0
# 3  314900.0  317990.0  318000.0
# 4  644000.0  650000.0  659650.0
#
# [5 rows x 119 columns]

# %%
state_df = cm_pric_df.groupby('State').mean()
state_df.head()
# Out:
#        StateCodeFIPS  MunicipalCodeFIPS     SizeRank        2010-01  \
# State
# AK               2.0         126.500000  1227.250000  245980.000000
# AL               1.0          69.156863  1010.019608  170256.000000
# AR               5.0          71.901961  1374.588235  144010.000000
# AZ               4.0          14.071429   587.571429  205049.538462
# CA               6.0          58.392857   578.928571  364862.473684
#
#              2010-02        2010-03        2010-04        2010-05  \
# State
# AK     248960.000000  249970.000000  253970.000000  257950.000000
# AL     168465.742857  166812.857143  162888.142857  163802.828571
# AR     143528.960000  142511.600000  142595.000000  144297.540000
# AZ     200438.230769  197146.153846  196438.461538  195640.384615
# CA     363374.460526  360437.500000  359070.868421  359761.078947
#
#              2010-06        2010-07  ...        2018-08        2018-09  \
# State                                ...
# AK     258500.000000  254050.000000  ...  314718.750000  308190.562500
# AL     164528.100000  164341.071429  ...  174244.705882  175496.323529
# AR     145772.000000  145984.000000  ...  143921.843137  144481.735294
# AZ     193250.000000  191703.038462  ...  256110.357143  254870.857143
# CA     359984.868421  356227.631579  ...  494830.000000  496406.848214
#
#              2018-10        2018-11        2018-12        2019-01  \
# State
# AK     306662.500000  308050.000000  305975.000000  313800.000000
# AL     173590.568627  174827.843137  174876.803922  175703.970588
# AR     143885.352941  143997.058824  144519.862745  144329.882353
# AZ     257583.178571  259314.285714  258430.000000  257853.678571
# CA     493805.616071  490460.169643  486545.008929  483991.035714
#
#              2019-02        2019-03        2019-04        2019-05
# State
# AK     314594.250000  317990.562500  317887.500000  319925.000000
# AL     176523.313725  180504.117647  184842.745098  183847.088235
# AR     144047.558824  147094.931373  150434.196078  149360.882353
# AZ     257705.714286  259163.142857  264953.928571  266500.000000
# CA     487133.848214  497491.410714  509799.375000  512148.392857
#
# [5 rows x 116 columns]

# %%
state_df1 = state_df.iloc[:,3:]


#Sort Counties by average price of property in 2019-05 - from the largest to the lowest
state_sorted = state_df1.sort_values(by ='2019-05',ascending=False )
state_sorted.head()
# Out:
#              2010-01        2010-02        2010-03        2010-04  \
# State
# HI     542191.250000  547749.750000  537875.000000  538974.000000
# DC     329501.000000  339400.000000  349700.000000  360000.000000
# CA     364862.473684  363374.460526  360437.500000  359070.868421
# MA     313858.333333  312891.666667  315000.000000  313958.333333
# CO     314784.785714  312681.785714  308705.357143  305563.214286
#
#              2010-05        2010-06        2010-07        2010-08  \
# State
# HI     537750.000000  530000.000000  523712.500000  531825.000000
# DC     360000.000000  359000.000000  350000.000000  349900.000000
# CA     359761.078947  359984.868421  356227.631579  354604.026316
# MA     315995.833333  314537.500000  309633.333333  306916.666667
# CO     305959.803571  302242.285714  301814.214286  301632.142857
#
#              2010-09        2010-10  ...        2018-08        2018-09  \
# State                                ...
# HI     516000.000000  511975.000000  ...  657475.000000  661861.000000
# DC     349500.000000  352900.000000  ...  577250.000000  589000.000000
# CA     348393.065789  341494.921053  ...  494830.000000  496406.848214
# MA     303845.833333  302912.500000  ...  484873.076923  485138.384615
# CO     294679.428571  292973.660714  ...  447036.565217  445699.630435
#
#              2018-10        2018-11        2018-12        2019-01  \
# State
# HI     653250.000000  666500.000000  670975.000000  673625.000000
# DC     589900.000000  584900.000000  574900.000000  575000.000000
# CA     493805.616071  490460.169643  486545.008929  483991.035714
# MA     483003.846154  480930.769231  480123.807692  485611.538462
# CO     450006.641304  458008.543478  459817.728261  464912.402174
#
#              2019-02        2019-03        2019-04        2019-05
# State
# HI     674975.000000  671750.000000  667500.000000  671500.000000
# DC     585000.000000  589900.000000  599900.000000  599000.000000
# CA     487133.848214  497491.410714  509799.375000  512148.392857
# MA     482196.076923  491303.461538  492303.846154  508665.576923
# CO     461144.739130  457401.097826  457843.217391  454954.108696
#
# [5 rows x 113 columns]

# %%
statel = list(state_sorted.index.values)
print (statel)
# Out:
# ['HI', 'DC', 'CA', 'MA', 'CO', 'RI', 'UT', 'OR', 'WA', 'NJ', 'AK', 'CT', 'VI', 'MD', 'ID', 'NV', 'WY', 'DE', 'NH', 'MT', 'AZ', 'VA', 'VT', 'FL', 'NY', 'NC', 'SD', 'ME', 'TX', 'ND', 'SC', 'NM', 'MN', 'GA', 'TN', 'LA', 'WI', 'NE', 'AL', 'PA', 'MS', 'MI', 'KY', 'IN', 'OK', 'OH', 'MO', 'WV', 'AR', 'IA', 'KS', 'IL', 'PR']

# %%
state_df2 = state_sorted.transpose()
state_df2.head()
# Out:
# State           HI        DC             CA             MA             CO  \
# 2010-01  542191.25  329501.0  364862.473684  313858.333333  314784.785714
# 2010-02  547749.75  339400.0  363374.460526  312891.666667  312681.785714
# 2010-03  537875.00  349700.0  360437.500000  315000.000000  308705.357143
# 2010-04  538974.00  360000.0  359070.868421  313958.333333  305563.214286
# 2010-05  537750.00  360000.0  359761.078947  315995.833333  305959.803571
#
# State          RI             UT             OR             WA             NJ  \
# 2010-01  324340.0  205939.285714  258379.166667  274854.758621  328511.619048
# 2010-02  321080.0  205375.000000  253406.250000  270936.724138  327888.071429
# 2010-03  316850.0  203506.428571  250875.000000  268898.275862  330235.690476
# 2010-04  314650.0  204196.357143  248451.041667  266858.620690  328856.809524
# 2010-05  314700.0  201525.000000  251064.583333  266722.620690  329788.095238
#
# State    ...             IN             OK             OH             MO  \
# 2010-01  ...  141693.794872  136034.375000  134962.479167  141528.804348
# 2010-02  ...  141917.487179  136021.734375  135985.427083  141307.706522
# 2010-03  ...  142277.564103  136145.171875  134353.693878  140908.315217
# 2010-04  ...  142225.243590  136064.843750  135258.500000  141443.436170
# 2010-05  ...  142585.089744  137863.281250  134956.071429  140726.265957
#
# State               WV         AR             IA             KS  \
# 2010-01  155733.055556  144010.00  140315.789474  128650.000000
# 2010-02  154884.722222  143528.96  140197.000000  128830.250000
# 2010-03  152968.888889  142511.60  140781.578947  129383.833333
# 2010-04  154354.138889  142595.00  142694.736842  128813.750000
# 2010-05  153641.666667  144297.54  142641.526316  128767.083333
#
# State               IL  PR
# 2010-01  145515.102041 NaN
# 2010-02  145521.632653 NaN
# 2010-03  146701.326531 NaN
# 2010-04  147497.244898 NaN
# 2010-05  148857.908163 NaN
#
# [5 rows x 53 columns]

# %%
#Graph % change from 2010 to 2019 from the largest to the smallest
plt.figure(figsize=(15,10))

plt.grid()
plt.bar(statel, state_df2.loc["2019-05",:], color = 'green', align='center', alpha=0.5)
#plt.bar(fail_med['Medicine'], fail_med["Change"], color = 'red', align='center', alpha=0.5)

#plt.xticks(y_pos, objects)
plt.ylabel('Average Price - US$')
plt.title('Average Price per Property in 2019-05')

plt.show()

# %%
# Calculate the average price percent changes from 2010 to 2019

changeS = []  #List to store the %change for each county

#Calculate %change for each medicine
for state in statel:
    dataS = state_df2[state]                       #Get tumor volume data for medicine
    changeS.append(((dataS['2019-05']/dataS['2011-02'])-1)*100)   #Calculate %change for medicine and add to list (change)
    
# Display the data to confirm
print (changeS)
# Out:
# [34.52869878793949, 76.6961651917404, 63.275508484212125, 74.74162068840226, 63.38411932756243, 33.728418744861614, 87.15884784287915, 50.808718283658315, 38.04585811646177, 12.961450352226844, 34.03929948047595, 15.51507106401484, nan, 26.55975237471022, 55.115956080208406, 78.40314364721293, 5.564266644064908, 23.27413511401579, 25.958671182960558, 11.632844274901322, 52.149381751779785, 15.109780615530276, 7.7462296264568575, 49.30020359928344, 21.061692482279092, 24.204106379701074, 45.43962985446848, 23.326382161212457, 42.262606263003974, 41.61224526404537, 23.136539828559478, 0.9976667225201075, 34.540710652323625, 31.54281544621542, 30.403398879387346, 23.666740782227148, 27.540502299325276, 51.95753813490873, 17.898904418982564, 10.219669043198465, 12.181430209721867, 44.9954920312446, 17.125476541284847, 22.924344041148892, 21.52460836754475, 30.36266259431435, 22.359758670725192, 5.54832479158478, 10.401789372465409, 11.100262587880572, 13.27070125609704, 1.894198962544924, -41.54886211512717]

# %%
# Store all Relevant Percent Changes into a Data Frame
stateS_10_19 = pd.DataFrame({"State": statel, "% Change": changeS})
stateS_10_19.head()
# Out:
#   State   % Change
# 0    HI  34.528699
# 1    DC  76.696165
# 2    CA  63.275508
# 3    MA  74.741621
# 4    CO  63.384119

# %%
#Order counties (in descending) based on % change between 2010 to 2019
dfS = stateS_10_19.sort_values(by ='% Change',ascending=False)
dfS.head(10)
# Out:
#    State   % Change
# 6     UT  87.158848
# 15    NV  78.403144
# 1     DC  76.696165
# 3     MA  74.741621
# 4     CO  63.384119
# 2     CA  63.275508
# 14    ID  55.115956
# 20    AZ  52.149382
# 37    NE  51.957538
# 7     OR  50.808718

# %%
#Graph % change from 2010 to 2019 from the largest to the smallest
plt.figure(figsize=(15,10))

plt.grid()
plt.bar(dfS['State'], dfS["% Change"], color = 'green', align='center', alpha=0.5)

#plt.xticks(y_pos, objects)
plt.ylabel('% Change in Average Price')
plt.title('% Change in Average Price between 2011 and 2019')

plt.show()
